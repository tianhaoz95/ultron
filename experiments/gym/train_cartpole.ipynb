# %% [markdown]
# <a href="https://colab.research.google.com/github/tianhaoz95/ultron/blob/master/experiments/gym/train_cartpole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train cartpole

# %%
# !mkdir -p ./project && rm -rf ./project/ultron && git clone https://github.com/tianhaoz95/ultron.git ./project/ultron && pip install -r ./project/ultron/requirements.txt
# Out:
# Cloning into './project/ultron'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 36 (delta 7), reused 23 (delta 3), pack-reused 0
# Unpacking objects: 100% (36/36), done.
# ...

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'project/ultron/experiments/gym')))
print(sys.path)
# Out:
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython', './project/ultron/experiments/gym', '/project/ultron/experiments/gym']

# %%
from master import MasterAgent

# %%
class MockArgs:
  def __init__(self):
    self.algorithm = 'a3c'
    self.lr = 0.001
    self.update_freq = 20
    self.max_eps = 2000
    self.gamma = 0.99
    self.save_dir = '/tmp/'
args = MockArgs()

# %%
master = MasterAgent(args)
# Out:
# 4 2

# %%
master.train()
# Out:
# Starting worker 0
# Starting worker 1
# Episode: 0 | Moving Average Reward: 13 | Episode Reward: 13 | Loss: 1.991 | Steps: 14 | Worker: 1
# Saving best model to /tmp/, episode score: 13.0
# Episode: 1 | Moving Average Reward: 12 | Episode Reward: 7 | Loss: 1.126 | Steps: 8 | Worker: 1
# Episode: 2 | Moving Average Reward: 13 | Episode Reward: 32 | Loss: 2.886 | Steps: 33 | Worker: 0
# Saving best model to /tmp/, episode score: 32.0
# Episode: 3 | Moving Average Reward: 13 | Episode Reward: 11 | Loss: 1.75 | Steps: 12 | Worker: 1
# Episode: 4 | Moving Average Reward: 13 | Episode Reward: 25 | Loss: 3.036 | Steps: 26 | Worker: 0
# Episode: 5 | Moving Average Reward: 13 | Episode Reward: 10 | Loss: 1.565 | Steps: 11 | Worker: 1
# Episode: 6 | Moving Average Reward: 13 | Episode Reward: 18 | Loss: 2.689 | Steps: 19 | Worker: 0
# Episode: 7 | Moving Average Reward: 13 | Episode Reward: 7 | Loss: 1.178 | Steps: 8 | Worker: 1
# ...
